# %%
#KÜMELER
#Kümeler, sırasız, değiştirilemez ve benzersiz elemanlardan oluşan veri yapılarıdır. Kümeler, süslü parantez {} içinde tanımlanır ve elemanlar virgülle ayrılır. Kümeler, matematikteki kümelere benzer şekilde çalışır ve birçok yerleşik yöntemle birlikte gelir.
