# %%
#PRINT() FONKSİYONU
"""
print() fonksiyonunun görevi verilen parametreyi ekrana çıktı olarak vermektir.
"""
print("Python programlama dili")
print('Mustafa', 'ÇEÇEN')
"""
print() Fonksiyonunun Parametreleri

--SEP--
sep ifadesi, İngilizcede separator (ayırıcı, ayraç) kelimesinin kısaltmasıdır. 
Dolayısıyla print() fonksiyonundaki bu sep parametresi, ekrana basılacak öğeler arasına hangi karakterin yerleştirileceğini gösterir. 
Bu parametrenin öntanımlı değeri bir adet boşluk karakteridir(” “). Yalnızca karakter dizilerini ve None parametresini alır.

>>> print("http://", "www.", "google.", "com", sep=" ")

--END--
print() fonksiyonuna verilen parametreleri birleştirirken bu parametrelerin sonuna neyin geleceğini belirler. 
Öntanımlı olarak, parametrelerin sonuna ‘satır başı karakteri’ ekler. Yalnızca karakter dizilerini ve None parametresini alır.

>>> print("Bugün günlerden Mustafa", end="\n")

--FİLE--
file'ın görevi, print() fonksiyonuna verilen karakter dizisi ve/veya sayıların, yani parametrelerin nereye yazılacağını belirtmektir. Bu parametrenin öntanımlı değeri sys.stdout’tur. 
sys.stdout,‘standart çıktı konumu’ anlamına gelir.

>>> dosya = open("deneme.txt", "w")
>>> print("Ben Python!", file=dosya)
>>> dosya.close()

--FLUSH--
Python, yazdırmak istenen bilgiyi standart çıktı konumuna gönderir. 
Ancak Python’da bazı işlemler standart çıktı konumuna gönderilmeden önce bir süre tamponda bekletir ve daha sonra bekleyen bu işlemler topluca standart çıktı konumuna gönderilir. 
Flush bu boşaltma mekanizmasını kontrol eder. True veya False parametrelerini alabilir. Bu parametrenin öntanımlı değeri False’tur.

>>> print("Merhaba Dünya!", file=f, flush=True)
"""
"""
format() metodu verilen parametreleri {} parantezleri arasına sırası ile yerleştirir.
"""
ad = "Mustafa"
soyad = "CECEN"
print("Adınız: {}, Soyadınız: {}".format(ad, soyad))

# %%
print("""
Mustafa
Çeçen
""")

# %%
print(*"Mustafa",sep=".") #bu yöntem sayılarda kullanılamaz.

# %%
"{0} {1} ({1} {0})".format("Mustafa", "Cecen")

# %%
birinci_rakam = 5
ikinci_rakam = 3

f'Rakamların toplamı {birinci_rakam + ikinci_rakam} eder.'
